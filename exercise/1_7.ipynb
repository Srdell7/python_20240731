# %%
import requests
from requests import Response
factory_url = 'https://data.ntpc.gov.tw/api/datasets/c51d5111-c300-44c9-b4f1-4b28b9929ca2/json?size=100'
try:
    res:Response = requests.request('GET',factory_url)
    res.raise_for_status()
except Exception:
    print('error')
else:
    content = res.text

from pydantic import BaseModel,RootModel,field_validator,Field,field_serializer
from datetime import datetime
from pprint import pprint

class Factory(BaseModel):
    廠名:str = Field(alias='organizer')
    註冊號碼:str = Field(alias='no')
    地址:str = Field(alias='address')
    統一編號:str = Field(alias='tax_id_number')
    經度:float|None = Field(alias='wgs84ax')
    緯度:float|None = Field(alias='wgs84ay')
    創始日期:datetime = Field(alias='date')
        
    @field_validator('經度','緯度',mode='before')
    @classmethod
    def number_float(cls,value:float):
        if value == None:
            return None
        else:
            return round(float(value), ndigits=5)
    
    @field_serializer('日期')
    def time(self,date:datetime)->str:
        return date.strftime('%Y/%m/%d')
    
class Shop(RootModel):
    root: list[Factory]

shops:Shop = Shop.model_validate_json(content)
shops_list = shops.model_dump()
pprint(shops_list)
# Out:
# [{'地址': '新北市新莊區新莊路四九三巷四弄一一號',
#   '廠名': '鴻輝食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '35567635',
#   '經度': 121.44862,
#   '緯度': 25.0327,
#   '註冊號碼': '99611344'},
#  {'地址': '新北市新莊區化成路三八二巷一八號',
#   '廠名': '廣達香食品股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35549807',
#   '經度': 121.46722,
#   '緯度': 25.0499,
#   '註冊號碼': '99604192'},
#  {'地址': '新北市板橋區縣民大道一段二八一號',
#   '廠名': '順發糧食行',
#   '日期': '1970/08/23',
#   '統一編號': '33305209',
#   '經度': 121.4605,
#   '緯度': 25.01011,
#   '註冊號碼': '99613990'},
#  {'地址': '新北市新莊區化成路二一九號',
#   '廠名': '台灣塩野香料股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '3561504',
#   '經度': 121.46569,
#   '緯度': 25.04674,
#   '註冊號碼': '99600477'},
#  {'地址': '新北市新莊區新樹路二六八巷二二號',
#   '廠名': '圓金釀造食品股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35427115',
#   '經度': 121.43106,
#   '緯度': 25.01403,
#   '註冊號碼': '99606467'},
#  {'地址': '新北市永和區仁愛路一四一巷五二號',
#   '廠名': '永芳醬園股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '33938534',
#   '經度': 121.51255,
#   '緯度': 25.01134,
#   '註冊號碼': '99605140'},
#  {'地址': '新北市三重區三和路4段77號2、3樓、79號1至6樓',
#   '廠名': '強生化學製藥廠股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35348007',
#   '經度': 121.48972,
#   '緯度': 25.07527,
#   '註冊號碼': '99606303'},
#  {'地址': '新北市淡水區中正路二巷一號',
#   '廠名': '大德製冰廠',
#   '日期': '1970/08/23',
#   '統一編號': '37011107',
#   '經度': 121.44366,
#   '緯度': 25.16967,
#   '註冊號碼': '99618950'},
#  {'地址': '新北市三峽區竹崙路140號',
#   '廠名': '臺灣農林股份有限公司北區分公司',
#   '日期': '1970/08/23',
#   '統一編號': '33506395',
#   '經度': 121.43492,
#   '緯度': 24.90929,
#   '註冊號碼': '99615941'},
#  {'地址': '新北市樹林區柑園街一段三四五號',
#   '廠名': '新成春碾米廠',
#   '日期': '1970/08/23',
#   '統一編號': '33326978',
#   '經度': 121.39073,
#   '緯度': 24.95631,
#   '註冊號碼': '99689303'},
#  {'地址': '新北市鶯歌區黃厝街３１巷１７號',
#   '廠名': '建興豆皮工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33230600',
#   '經度': 121.34359,
#   '緯度': 24.94554,
#   '註冊號碼': '99615451'},
#  {'地址': '新北市鶯歌區尖山路二０四號',
#   '廠名': '永順豆皮工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33084901',
#   '經度': 121.3437,
#   '緯度': 24.94711,
#   '註冊號碼': '99689798'},
#  {'地址': '新北市新莊區新莊路六七、六九號',
#   '廠名': '華泰行食品工廠',
#   '日期': '1970/08/23',
#   '統一編號': '35913896',
#   '經度': 121.45755,
#   '緯度': 25.03679,
#   '註冊號碼': '99606385'},
#  {'地址': '新北市新莊區新莊路128號',
#   '廠名': '翁裕美商行',
#   '日期': '1970/08/23',
#   '統一編號': '35320057',
#   '經度': 121.45569,
#   '緯度': 25.0359,
#   '註冊號碼': '99610825'},
#  {'地址': '新北市金山區美田里中山路218號',
#   '廠名': '集發米廠',
#   '日期': '1970/08/23',
#   '統一編號': '37144900',
#   '經度': 121.63742,
#   '緯度': 25.22196,
#   '註冊號碼': '99690225'},
#  {'地址': '新北市淡水區中正路一七０號',
#   '廠名': '和利碾米工廠',
#   '日期': '1970/08/23',
#   '統一編號': '37065905',
#   '經度': 121.4405,
#   '緯度': 25.1699,
#   '註冊號碼': '99619195'},
#  {'地址': '新北市中和區中山路二段三二九號',
#   '廠名': '桂冠實業股份有限公司中和一廠',
#   '日期': '1970/08/23',
#   '統一編號': '18868215',
#   '經度': 121.49291,
#   '緯度': 25.00221,
#   '註冊號碼': '99616659'},
#  {'地址': '新北市三重區光復路二段一四０號',
#   '廠名': '建豐實業股份有限公司二重工廠',
#   '日期': '1970/08/23',
#   '統一編號': '15276906',
#   '經度': 121.47197,
#   '緯度': 25.05959,
#   '註冊號碼': '99613703'},
#  {'地址': '新北市新店區永業路96號',
#   '廠名': '林源昌蔴油食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '30831740',
#   '經度': 121.53042,
#   '緯度': 24.95071,
#   '註冊號碼': '99619056'},
#  {'地址': '新北市板橋區觀光街五八號',
#   '廠名': '信成油廠股份有限公司板橋分廠',
#   '日期': '1970/08/23',
#   '統一編號': '11473808',
#   '經度': 121.47017,
#   '緯度': 25.01665,
#   '註冊號碼': '99617209'},
#  {'地址': '新北市新莊區幸福東路六０號',
#   '廠名': '新合記實業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '34014947',
#   '經度': 121.46491,
#   '緯度': 25.0496,
#   '註冊號碼': '99610362'},
#  {'地址': '新北市板橋區南雅南路一段四巷一六號',
#   '廠名': '傳貴豆皮工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33666478',
#   '經度': 121.45464,
#   '緯度': 25.00521,
#   '註冊號碼': '99618617'},
#  {'地址': '新北市深坑區文山路1段33號',
#   '廠名': '樂口福食品股份有限公司深坑工廠',
#   '日期': '1970/08/23',
#   '統一編號': '19087104',
#   '經度': 121.62942,
#   '緯度': 25.00351,
#   '註冊號碼': '99600358'},
#  {'地址': '新北市三芝區橫山路一三之一號',
#   '廠名': '南亞茶業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '33759594',
#   '經度': 121.50095,
#   '緯度': 25.25772,
#   '註冊號碼': '99689894'},
#  {'地址': '新北市板橋區文化路一段四二一巷二七號',
#   '廠名': '天興豆腐店',
#   '日期': '1970/08/23',
#   '統一編號': '33033621',
#   '經度': 121.46605,
#   '緯度': 25.02324,
#   '註冊號碼': '99689352'},
#  {'地址': '新北市瑞芳區大寮路八四號',
#   '廠名': '鴻明冷凍食品股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '4545428',
#   '經度': 121.78155,
#   '緯度': 25.10019,
#   '註冊號碼': '99690131'},
#  {'地址': '新北市新莊區福營路二二七巷二三號',
#   '廠名': '濟生股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '4309819',
#   '經度': 121.43026,
#   '緯度': 25.02946,
#   '註冊號碼': '99612784'},
#  {'地址': '新北市新莊區化成路三八九巷六六號',
#   '廠名': '永利油廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35874319',
#   '經度': 121.46305,
#   '緯度': 25.05809,
#   '註冊號碼': '99610191'},
#  {'地址': '新北市泰山區貴和里貴陽街五號',
#   '廠名': '富記食品有限公司泰山廠',
#   '日期': '1970/08/23',
#   '統一編號': '4274706',
#   '經度': 121.42133,
#   '緯度': 25.03347,
#   '註冊號碼': '99615544'},
#  {'地址': '新北市新莊區思源路九二號',
#   '廠名': '中立食品工業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '27005133',
#   '經度': 121.46022,
#   '緯度': 25.04573,
#   '註冊號碼': '99610549'},
#  {'地址': '新北市土城區工業區大同街一五之一號',
#   '廠名': '鮮太王食品工業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '97198133',
#   '經度': 121.44281,
#   '緯度': 24.97257,
#   '註冊號碼': '99603189'},
#  {'地址': '新北市新莊區中正路六一巷三號',
#   '廠名': '振記冷藏股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35858269',
#   '經度': 121.4623,
#   '緯度': 25.0393,
#   '註冊號碼': '99605752'},
#  {'地址': '新北市中和區連城路二一六、二一八號',
#   '廠名': '德合豆沙工廠',
#   '日期': '1970/08/23',
#   '統一編號': '34157727',
#   '經度': 121.49146,
#   '緯度': 24.9966,
#   '註冊號碼': '99617720'},
#  {'地址': '新北市板橋區干城路一五九號',
#   '廠名': '三順冷凍有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '27474851',
#   '經度': 121.46073,
#   '緯度': 24.99217,
#   '註冊號碼': '99606653'},
#  {'地址': '新北市淡水區椿子林二０之一號',
#   '廠名': '有豐食品股份有限公司淡水廠',
#   '日期': '1970/08/23',
#   '統一編號': '89590248',
#   '經度': 121.48194,
#   '緯度': 25.20372,
#   '註冊號碼': '99606991'},
#  {'地址': '新北市新莊區化成路389巷18號',
#   '廠名': '樺興化學工業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '35940916',
#   '經度': 121.46444,
#   '緯度': 25.05839,
#   '註冊號碼': '99610519'},
#  {'地址': '新北市淡水區坪頂里小平頂二三之一二號',
#   '廠名': '文興食品工業股份有限公司淡水廠',
#   '日期': '1970/08/23',
#   '統一編號': '31133342',
#   '經度': 121.47558,
#   '緯度': 25.15634,
#   '註冊號碼': '99690093'},
#  {'地址': '新北市淡水區行忠路328號',
#   '廠名': '大醇食品股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '5078012',
#   '經度': 121.46086,
#   '緯度': 25.19992,
#   '註冊號碼': '99600313'},
#  {'地址': '新北市板橋區中山路二段一四八巷三四號',
#   '廠名': '代岱食品工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33976733',
#   '經度': 121.47701,
#   '緯度': 25.01609,
#   '註冊號碼': '99609940'},
#  {'地址': '新北市三重區中興北街一五０巷三一號',
#   '廠名': '台研食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '34095722',
#   '經度': 121.46769,
#   '緯度': 25.05648,
#   '註冊號碼': '99604829'},
#  {'地址': '新北市樹林區三俊街一五九巷三五號',
#   '廠名': '寶龍食品廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '34463752',
#   '經度': 121.41913,
#   '緯度': 25.01665,
#   '註冊號碼': '99610486'},
#  {'地址': '新北市淡水區小坑子頭5之1號',
#   '廠名': '台灣留蘭香股份有限公司大屯廠',
#   '日期': '1970/08/23',
#   '統一編號': '4375248',
#   '經度': 121.48337,
#   '緯度': 25.21274,
#   '註冊號碼': '99617087'},
#  {'地址': '新北市汐止區八連路一段七八巷一號',
#   '廠名': '振源食品科技股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '18852136',
#   '經度': 121.64345,
#   '緯度': 25.08083,
#   '註冊號碼': '99689272'},
#  {'地址': '新北市土城區民權街14號',
#   '廠名': '昌桔食品有限公司土城廠',
#   '日期': '1970/08/23',
#   '統一編號': '80537594',
#   '經度': 121.4158,
#   '緯度': 24.9644,
#   '註冊號碼': '99600293'},
#  {'地址': '新北市樹林區三俊街九０巷六、八號',
#   '廠名': '高印昌股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '24259062',
#   '經度': 121.41422,
#   '緯度': 25.01523,
#   '註冊號碼': '99614371'},
#  {'地址': '新北市中和區中山路二段三八七號',
#   '廠名': '東鈴冷凍股份有限公司二廠',
#   '日期': '1970/08/23',
#   '統一編號': '34334097',
#   '經度': 121.48696,
#   '緯度': 25.00455,
#   '註冊號碼': '99611707'},
#  {'地址': '新北市瑞芳區頂坪路一三五號',
#   '廠名': '華昇食品工廠股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '33853036',
#   '經度': 121.79301,
#   '緯度': 25.10205,
#   '註冊號碼': '99600865'},
#  {'地址': '新北市樹林區佳園路一段90號',
#   '廠名': '欣和興食品股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '16247280',
#   '經度': 121.39339,
#   '緯度': 24.96933,
#   '註冊號碼': '99608390'},
#  {'地址': '新北市中和區安邦街一四號',
#   '廠名': '寒山物產商業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '34342809',
#   '經度': 121.49581,
#   '緯度': 24.99821,
#   '註冊號碼': '99618736'},
#  {'地址': '新北市新莊區頭前路二巷七號',
#   '廠名': '松記食品工業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '36031978',
#   '經度': 121.46834,
#   '緯度': 25.05319,
#   '註冊號碼': '99611202'},
#  {'地址': '新北市新莊區思源路84巷5號',
#   '廠名': '中立食品工業股份有限公司新莊二廠',
#   '日期': '1970/08/23',
#   '統一編號': '27005133',
#   '經度': 121.46074,
#   '緯度': 25.04542,
#   '註冊號碼': '99610930'},
#  {'地址': '新北市新莊區頭前路一九號三樓',
#   '廠名': '臺灣威化企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '2082674',
#   '經度': 121.46801,
#   '緯度': 25.05258,
#   '註冊號碼': '99601779'},
#  {'地址': '新北市泰山區明志路三段四０七巷五號',
#   '廠名': '佑福食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '86272368',
#   '經度': 121.42164,
#   '緯度': 25.03389,
#   '註冊號碼': '99601668'},
#  {'地址': '新北市汐止區連興街一四八巷一號一樓',
#   '廠名': '雙氏企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '39611134',
#   '經度': 121.65392,
#   '緯度': 25.06123,
#   '註冊號碼': '99605164'},
#  {'地址': '新北市瑞芳區頂坪路一二號',
#   '廠名': '立基食品股份有限公司瑞芳一廠',
#   '日期': '1970/08/23',
#   '統一編號': '30888763',
#   '經度': 121.79122,
#   '緯度': 25.09768,
#   '註冊號碼': '99602072'},
#  {'地址': '新北市土城區永豐路一九五巷二三號',
#   '廠名': '頂昌企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '23832998',
#   '經度': 121.47412,
#   '緯度': 24.97958,
#   '註冊號碼': '99607109'},
#  {'地址': '新北市板橋區三民路二段二四五巷四弄一四號一樓',
#   '廠名': '智慧餅店',
#   '日期': '1970/08/23',
#   '統一編號': '8542387',
#   '經度': 121.48055,
#   '緯度': 25.01225,
#   '註冊號碼': '99690087'},
#  {'地址': '新北市新店區安泰路六０巷九０弄七八號',
#   '廠名': '口洛佳食品實業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '86611732',
#   '經度': 121.48365,
#   '緯度': 24.94465,
#   '註冊號碼': '99606737'},
#  {'地址': '新北市新莊區化成路一００之一號',
#   '廠名': '三豐食品工廠',
#   '日期': '1970/08/23',
#   '統一編號': '1995321',
#   '經度': 121.46535,
#   '緯度': 25.04413,
#   '註冊號碼': '99604702'},
#  {'地址': '新北市板橋區觀光街六一號',
#   '廠名': '吉美食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '34110272',
#   '經度': 121.47041,
#   '緯度': 25.01643,
#   '註冊號碼': '99607282'},
#  {'地址': '新北市板橋區大觀路三段三六巷八九弄八號',
#   '廠名': '伍弘實業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '34113502',
#   '經度': 121.434,
#   '緯度': 24.99804,
#   '註冊號碼': '99604376'},
#  {'地址': '新北市瑞芳區中正路八八號',
#   '廠名': '金瑞珍糕餅店',
#   '日期': '1970/08/23',
#   '統一編號': '33868657',
#   '經度': 121.80536,
#   '緯度': 25.10776,
#   '註冊號碼': '99689933'},
#  {'地址': '新北市中和區中山路二段三八０巷三號',
#   '廠名': '聯淳國際股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '97014959',
#   '經度': 121.49098,
#   '緯度': 25.00366,
#   '註冊號碼': '99606854'},
#  {'地址': '新北市汐止區大同路一段一四六巷一二號',
#   '廠名': '上好食品廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '23108926',
#   '經度': 121.63193,
#   '緯度': 25.05479,
#   '註冊號碼': '99619158'},
#  {'地址': '新北市三重區自強路四段三一巷八號一樓',
#   '廠名': '茄苳實業廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '36363526',
#   '經度': 121.48947,
#   '緯度': 25.07686,
#   '註冊號碼': '99618202'},
#  {'地址': '新北市三重區中正北路三四三、三四五號',
#   '廠名': '達益食品工業股份有限公司大有廠',
#   '日期': '1970/08/23',
#   '統一編號': '35466600',
#   '經度': 121.47297,
#   '緯度': 25.07177,
#   '註冊號碼': '99604243'},
#  {'地址': '新北市三重區重陽路一段一一三巷一弄三九號',
#   '廠名': '易成食品企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '36252330',
#   '經度': 121.48789,
#   '緯度': 25.05882,
#   '註冊號碼': '99612669'},
#  {'地址': '新北市三峽區橫溪路九九巷二六號',
#   '廠名': '貴州醬業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '1864046',
#   '經度': 121.40032,
#   '緯度': 24.93658,
#   '註冊號碼': '99603622'},
#  {'地址': '新北市土城區慶祥街一０二號',
#   '廠名': '寶島油脂股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '86992107',
#   '經度': 121.43543,
#   '緯度': 24.97264,
#   '註冊號碼': '99603846'},
#  {'地址': '新北市淡水區學府路一九四、一九六號一樓',
#   '廠名': '品良食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '37507959',
#   '經度': 121.44693,
#   '緯度': 25.17619,
#   '註冊號碼': '99604154'},
#  {'地址': '新北市中和區中正路一二０六巷一九號一、二樓',
#   '廠名': '生豐食品廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '23478286',
#   '經度': 121.48017,
#   '緯度': 25.01152,
#   '註冊號碼': '99689149'},
#  {'地址': '新北市鶯歌區鶯桃路94巷59弄8號1樓',
#   '廠名': '奕嘉食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '1871617',
#   '經度': 121.34159,
#   '緯度': 24.95533,
#   '註冊號碼': '99617796'},
#  {'地址': '新北市瑞芳區\ue756魚坑路二００號',
#   '廠名': '阜晟企業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '940171',
#   '經度': 121.79043,
#   '緯度': 25.10977,
#   '註冊號碼': '99691118'},
#  {'地址': '新北市淡水區下圭柔山一一九之一二號',
#   '廠名': '銘珍食品廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '7553202',
#   '經度': 121.45279,
#   '緯度': 25.2076,
#   '註冊號碼': '99618971'},
#  {'地址': '新北市板橋區干城路一三九號三、四樓',
#   '廠名': '和益製麵廠股份有限公司板橋廠',
#   '日期': '1970/08/23',
#   '統一編號': '16648475',
#   '經度': 121.45986,
#   '緯度': 24.99329,
#   '註冊號碼': '99607756'},
#  {'地址': '新北市板橋區廣新里懷仁街一０巷三號',
#   '廠名': '萬年春茶業股份有限公司板橋廠',
#   '日期': '1970/08/23',
#   '統一編號': '30965830',
#   '經度': None,
#   '緯度': None,
#   '註冊號碼': '99619903'},
#  {'地址': '新北市新莊區化成路三七五巷三五、三七號',
#   '廠名': '芳福企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22057097',
#   '經度': 121.46399,
#   '緯度': 25.05769,
#   '註冊號碼': '99609192'},
#  {'地址': '新北市樹林區寶園街11號',
#   '廠名': '新北市樹林區農會稻穀加工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33421903',
#   '經度': 121.38649,
#   '緯度': 24.95344,
#   '註冊號碼': '99600370'},
#  {'地址': '新北市新莊區化成路一九０巷一二號',
#   '廠名': '大安好食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '16650113',
#   '經度': 121.46626,
#   '緯度': 25.0465,
#   '註冊號碼': '99611003'},
#  {'地址': '新北市樹林區武林街9號之6（1~3樓）',
#   '廠名': '芬芳烹材股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '84503548',
#   '經度': 121.41829,
#   '緯度': 25.00216,
#   '註冊號碼': '99600563'},
#  {'地址': '新北市三重區中正北路一五號',
#   '廠名': '蘇州采芝齋食品行',
#   '日期': '1970/08/23',
#   '統一編號': '33899201',
#   '經度': 121.49264,
#   '緯度': 25.06168,
#   '註冊號碼': '99612481'},
#  {'地址': '新北市瑞芳區頂坪路七八號',
#   '廠名': '品川實業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22173693',
#   '經度': 121.79301,
#   '緯度': 25.10205,
#   '註冊號碼': '99600911'},
#  {'地址': '新北市三峽區成福路247、249號',
#   '廠名': '富山共同製茶廠',
#   '日期': '1970/08/23',
#   '統一編號': '1924348',
#   '經度': 121.42668,
#   '緯度': 24.92503,
#   '註冊號碼': '99609881'},
#  {'地址': '新北市中和區橋和路九五號',
#   '廠名': '大人行實業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '5152960',
#   '經度': 121.49055,
#   '緯度': 25.00562,
#   '註冊號碼': '99618781'},
#  {'地址': '新北市中和區自立路一四一巷九號一樓',
#   '廠名': '良億食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '2368973',
#   '經度': 121.52281,
#   '緯度': 24.99365,
#   '註冊號碼': '99689691'},
#  {'地址': '新北市新店區民權路一五七、一五九號三樓',
#   '廠名': '欣裕食品有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22247203',
#   '經度': 121.53403,
#   '緯度': 24.98264,
#   '註冊號碼': '99605944'},
#  {'地址': '新北市三重區中正北路25巷21號1樓',
#   '廠名': '虎林食品行',
#   '日期': '1970/08/23',
#   '統一編號': '1976582',
#   '經度': 121.4931,
#   '緯度': 25.0625,
#   '註冊號碼': '99612911'},
#  {'地址': '新北市永和區永貞路三二０號一樓',
#   '廠名': '王一企業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '31256006',
#   '經度': 121.51166,
#   '緯度': 25.00512,
#   '註冊號碼': '99689753'},
#  {'地址': '新北市坪林區坪林里二六號一樓',
#   '廠名': '祥茂糖菓工廠',
#   '日期': '1970/08/23',
#   '統一編號': '33821909',
#   '經度': 121.71284,
#   '緯度': 24.94237,
#   '註冊號碼': '99619694'},
#  {'地址': '新北市新莊區自立街二一四巷一０弄二二號一樓',
#   '廠名': '漢點食品工廠有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22768929',
#   '經度': 121.45637,
#   '緯度': 25.04497,
#   '註冊號碼': '99605227'},
#  {'地址': '新北市土城區慶祥街四二號',
#   '廠名': '順溢油業有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22223119',
#   '經度': 121.43691,
#   '緯度': 24.97453,
#   '註冊號碼': '99604153'},
#  {'地址': '新北市中和區中正路1226號5樓之1',
#   '廠名': '青峰實業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '20790729',
#   '經度': 121.47942,
#   '緯度': 25.01099,
#   '註冊號碼': '99605201'},
#  {'地址': '新北市汐止區大同路一段三三七巷一六弄一八號',
#   '廠名': '信好食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '2296964',
#   '經度': 121.63752,
#   '緯度': 25.06095,
#   '註冊號碼': '99617575'},
#  {'地址': '新北市樹林區光武街三六巷一號',
#   '廠名': '聯米企業股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '86213452',
#   '經度': 121.41708,
#   '緯度': 25.00633,
#   '註冊號碼': '99613616'},
#  {'地址': '新北市汐止區大同路1段358號',
#   '廠名': '青映食品冷凍股份有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '22389173',
#   '經度': 121.64028,
#   '緯度': 25.06024,
#   '註冊號碼': '99605340'},
#  {'地址': '新北市新店區中正路五四二之一號四樓',
#   '廠名': '國暉國際有限公司',
#   '日期': '1970/08/23',
#   '統一編號': '4890618',
#   '經度': 121.53379,
#   '緯度': 24.98455,
#   '註冊號碼': '99604859'},
#  {'地址': '新北市樹林區中山路一段九一號一樓',
#   '廠名': '竹軒西點麵包店',
#   '日期': '1970/08/23',
#   '統一編號': '34205093',
#   '經度': 121.42339,
#   '緯度': 24.99116,
#   '註冊號碼': '99604924'},
#  {'地址': '新北市新莊區化成路二九巷八六號',
#   '廠名': '上發食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '2163161',
#   '經度': 121.46215,
#   '緯度': 25.04409,
#   '註冊號碼': '99610365'},
#  {'地址': '新北市土城區亞洲路五八巷五弄一八號',
#   '廠名': '頂嘉麻油食品工廠',
#   '日期': '1970/08/23',
#   '統一編號': '1927160',
#   '經度': 121.43412,
#   '緯度': 24.97369,
#   '註冊號碼': '99601564'},
#  {'地址': '新北市林口區中正路二五九號一樓',
#   '廠名': '元福美食品廠',
#   '日期': '1970/08/23',
#   '統一編號': '35838807',
#   '經度': 121.39046,
#   '緯度': 25.07759,
#   '註冊號碼': '99604287'}]
